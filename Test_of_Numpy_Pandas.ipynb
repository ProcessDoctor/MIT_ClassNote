# %% [markdown]
# <a href="https://colab.research.google.com/github/ProcessDoctor/MIT_ClassNote/blob/main/Test_of_Numpy_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the libraries
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path= "/content/drive/MyDrive/Week 1  Foundations Python and Statistics/Dateset_ODI+-+Dateset_ODI.csv"
data=pd.read_csv(path)

# %%
import numpy as np
a=np.array([1,10,2,0])
np.power(a,2)
# Out:
# array([  1, 100,   4,   0])

# %%
import numpy as np
array=np.arange(10)

np.hsplit(array,2)
# Out:
# [array([0, 1, 2, 3, 4]), array([5, 6, 7, 8, 9])]

# %%
import numpy as np
array1=np.array([1,0,0,1,0])
array2=np.arange(6)
#array1+array2

# %%
np.arange(6)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
data.dtypes
# Out:
# Scorecard     object
# Team 1        object
# Team 2        object
# Winner        object
# Margin        object
# Ground        object
# Match Date    object
# dtype: object

# %%
#checking missing values
data.isna().sum()
#or
#data.isnull().sum()
# Out:
# Scorecard       0
# Team 1          0
# Team 2          0
# Winner          0
# Margin        179
# Ground          0
# Match Date      0
# dtype: int64

# %%
fiftiethmatchwinner=data.iloc[49]['Winner']
print(fiftiethmatchwinner)
# Out:
# England

# %%
devon=data[data['Ground']=='Devonport']
num_devon=len(devon)
print(num_devon)
# Out:
# 1

# %%
winner_Australia=(data['Winner']=='Australia').sum()

print(winner_Australia)
# Out:
# 555

# %%
winner_Team2=(data['Winner']==data['Team 2']).sum()

print(winner_Team2)
# Out:
# 1637

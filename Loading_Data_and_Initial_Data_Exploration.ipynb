# %% [markdown]
# <a href="https://colab.research.google.com/github/ProcessDoctor/MIT_ClassNote/blob/main/Loading_Data_and_Initial_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.float_format", lambda x: "%.3f" %x) #to restrict any float number to 3dp

# %%
#accessing my file from my google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#importing the dataset to be utilized
path= "/content/drive/MyDrive/Week 1  Foundations Python and Statistics/Melbourne_Housing.csv"
data=pd.read_csv(path)

# %%
#viewing the data
data.head(5)
# Out:
#          Suburb  Rooms Type        SellerG        Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson  03-09-2016    13.500  3042.000
# 1   Albert Park      2    h  hockingstuart  03-09-2016     3.300  3206.000
# 2   Albert Park      2    h        Thomson  03-09-2016     3.300  3206.000
# 3    Alphington      4    h          Brace  03-09-2016     6.400  3078.000
# 4    Alphington      3    h         Jellis  03-09-2016     6.400  3078.000
#
#    Bedroom  Bathroom   Car  Landsize BuildingArea  YearBuilt  \
# 0    3.000     2.000 1.000   303.000          225   2016.000
# 1    2.000     1.000 0.000   120.000           82   1900.000
# 2    2.000     1.000 0.000   159.000          inf        NaN
# 3    3.000     2.000 4.000   853.000          263   1930.000
# 4    3.000     2.000 2.000   208.000          inf   2013.000
#
#               Regionname  Propertycount    Price
# 0   Western Metropolitan           3464   840000
# ...

# %%
data.tail(3)
# Out:
#                  Suburb  Rooms Type    SellerG        Date  Distance  \
# 27111     Roxburgh Park      4    h      Raine  30-09-2017    20.600
# 27112  Springvale South      3    h  Harcourts  30-09-2017    22.200
# 27113       Westmeadows      4    h      Barry  30-09-2017    16.500
#
#        Postcode  Bedroom  Bathroom   Car  Landsize BuildingArea  YearBuilt  \
# 27111  3064.000    4.000     2.000 2.000       NaN          225   1995.000
# 27112  3172.000    3.000     2.000 1.000   544.000          NaN        NaN
# 27113  3049.000    4.000     2.000 6.000   813.000          140   1960.000
#
#                        Regionname  Propertycount   Price
# 27111       Northern Metropolitan           5833  591000
# 27112  South-Eastern Metropolitan           4054  780500
# 27113       Northern Metropolitan           2474  791000

# %%
#Shape of my dataset
data.shape
print("There are", data.shape[0], "rows and", data.shape[1], "columns.")
# Out:
# There are 27114 rows and 16 columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  object
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10543 non-null  object
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 3.3+ MB

# %%
#Changing the data type of the date column
data["Date"]=pd.to_datetime(data["Date"], format="%d-%m-%Y")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10543 non-null  object
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(3), object(5)
# ...

# %%
data.head()
# Out:
#          Suburb  Rooms Type        SellerG       Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson 2016-09-03    13.500  3042.000
# 1   Albert Park      2    h  hockingstuart 2016-09-03     3.300  3206.000
# 2   Albert Park      2    h        Thomson 2016-09-03     3.300  3206.000
# 3    Alphington      4    h          Brace 2016-09-03     6.400  3078.000
# 4    Alphington      3    h         Jellis 2016-09-03     6.400  3078.000
#
#    Bedroom  Bathroom   Car  Landsize BuildingArea  YearBuilt  \
# 0    3.000     2.000 1.000   303.000          225   2016.000
# 1    2.000     1.000 0.000   120.000           82   1900.000
# 2    2.000     1.000 0.000   159.000          inf        NaN
# 3    3.000     2.000 4.000   853.000          263   1930.000
# 4    3.000     2.000 2.000   208.000          inf   2013.000
#
#               Regionname  Propertycount    Price
# 0   Western Metropolitan           3464   840000
# 1  Southern Metropolitan           3280  1275000
# ...

# %%
#Why the Building Area column has object data type
data["BuildingArea"].unique()
# Out:
# array(['225', '82', 'inf', '263', '242', '251', '117', 'missing', '76',
#        '399', '118', '103', '180', '123', '218', '129', '167', '154',
#        '275', '121', nan, '125', '255', '75', '156', '240', '268', '108',
#        '69', '140', '214', '253', '189', '215', '96', '104', '100', '313',
#        '144', '93', '110', '70', '122', '51', '147', '113', '83', '56',
#        '137', '85', '64', '175', '3558', '170', '265', '353', '138', '19',
#        '116', '87', '74', '320', '300', '210', '120', '86', '97', '200',
#        '106', '14', '161', '128', '185', '146', '133', '115', '143',
#        '150', '195', '236', '276', '188', '179', '249', '141', '34', '73',
#        '107', '84', '81', '207', '50', '264', '312', '235', '221', '183',
#        '132', '160', '186', '78', '105', '145', '62', '220', '315', '181',
#        '61', '112', '420', '226', '266', '410', '449', '356', '477',
#        '250', '95', '190', '284', '247', '213', '209', '119', '111',
# ...

# %% [markdown]
# It is difficult to analyze each point to find the categorical values in the column. Let's find the count of non-numeric values and see what are these values

# %%
#Checking the count of different data types in BuildingArea column
data["BuildingArea"].apply(type).value_counts()
# Out:
# BuildingArea
# <class 'float'>    16571
# <class 'str'>      10543
# Name: count, dtype: int64

# %% [markdown]
# It is made of mixed data type like 'missing', 'inf' which should actually be read as missing values (NaN). Let's replace such data with null values.

# %%
#replacing values with nan
data["BuildingArea"]=data["BuildingArea"].replace(["missing", "inf"], np.nan)

# %%
#changing the data type to float
data["BuildingArea"]=data["BuildingArea"].astype(float)

# %%
#Let's check the data type of columns again
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(4)
# ...

# %% [markdown]
# It is also possible to replace missing and inf to NaN while loading  the data.

# %%
#using na_values to tell python which values it should consider as NaN
path= "/content/drive/MyDrive/Week 1  Foundations Python and Statistics/Melbourne_Housing.csv"
data_new=pd.read_csv(path, na_values=["missing", "inf"],)

# %% [markdown]
# This method is useful when we know wgat kind of values to consider as anomalies in the data.

# %%
data_new["BuildingArea"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# We observe that now building area is being considered as float after the 'missing' and 'inf' were read as NaN

# %% [markdown]
# **What are missing values**
#
# Missing values occur when no data value is stored for the variable in observation. Missing data are a common occurence and can have a significant effect on the conclusions that can be drawn from the data.

# %%
#To check the unique values in BuildingArea column
data['BuildingArea'].unique()
# Out:
# array([ 225.    ,   82.    ,       nan,  263.    ,  242.    ,  251.    ,
#         117.    ,   76.    ,  399.    ,  118.    ,  103.    ,  180.    ,
#         123.    ,  218.    ,  129.    ,  167.    ,  154.    ,  275.    ,
#         121.    ,  125.    ,  255.    ,   75.    ,  156.    ,  240.    ,
#         268.    ,  108.    ,   69.    ,  140.    ,  214.    ,  253.    ,
#         189.    ,  215.    ,   96.    ,  104.    ,  100.    ,  313.    ,
#         144.    ,   93.    ,  110.    ,   70.    ,  122.    ,   51.    ,
#         147.    ,  113.    ,   83.    ,   56.    ,  137.    ,   85.    ,
#          64.    ,  175.    , 3558.    ,  170.    ,  265.    ,  353.    ,
#         138.    ,   19.    ,  116.    ,   87.    ,   74.    ,  320.    ,
#         300.    ,  210.    ,  120.    ,   86.    ,   97.    ,  200.    ,
#         106.    ,   14.    ,  161.    ,  128.    ,  185.    ,  146.    ,
#         133.    ,  115.    ,  143.    ,  150.    ,  195.    ,  236.    ,
# ...

# %% [markdown]
# Checking missing values, duplicate values, and statistical summary

# %%
#What are missing values?
#Missing values take place when no data value is stored for the variable in an observation.
#Missing data are a common occurence and can have a significant effect on the conclusions that can be drawn from the data

# %% [markdown]
# **Checking for missing value in the data**

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom           6436
# Bathroom          6442
# Car               6817
# Landsize          9241
# BuildingArea     16585
# YearBuilt        15129
# Regionname           0
# Propertycount        0
# Price                0
# dtype: int64

# %% [markdown]
# **There are missing values in 8 columns of the data**
#
# **We will treat these missing values after understanding the distributions of features in the data, the relationships that exist in the data. This will help us impute these values more effectively**

# %% [markdown]
# **Checking for duplicate entries in the data**

# %%
data.duplicated().sum()
# Out:
# 11

# %% [markdown]
# **This implies that there are 11 duplicate entries in the data that needs to be removed or speak with the owners of the data if they could fix that**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(4)
# ...

# %%
data.isnull()
# Out:
#        Suburb  Rooms   Type  SellerG   Date  Distance  Postcode  Bedroom  \
# 0       False  False  False    False  False     False     False    False
# 1       False  False  False    False  False     False     False    False
# 2       False  False  False    False  False     False     False    False
# 3       False  False  False    False  False     False     False    False
# 4       False  False  False    False  False     False     False    False
# ...       ...    ...    ...      ...    ...       ...       ...      ...
# 27109   False  False  False    False  False     False     False    False
# 27110   False  False  False    False  False     False     False    False
# 27111   False  False  False    False  False     False     False    False
# 27112   False  False  False    False  False     False     False    False
# 27113   False  False  False    False  False     False     False    False
#
#        Bathroom    Car  Landsize  BuildingArea  YearBuilt  Regionname  \
# ...

# %%
data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom           6436
# Bathroom          6442
# Car               6817
# Landsize          9241
# BuildingArea     16585
# YearBuilt        15129
# Regionname           0
# Propertycount        0
# Price                0
# dtype: int64

# %% [markdown]
# we have 27k rows of data, and there are some missing values, we need to improve the data before we continue our analysis

# %% [markdown]
# **Check for duplicate entries in the data**

# %%
data.duplicated().sum()
# Out:
# 11

# %% [markdown]
# **11 duplicate entries in the data**

# %%
#dropping duplicate entries from the data
data.drop_duplicates(inplace=True)

# %%
#resetting the index of the data since some rows will be removed
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#                  Suburb  Rooms Type        SellerG       Date  Distance  \
# 0          Airport West      3    t         Nelson 2016-09-03    13.500
# 1           Albert Park      2    h  hockingstuart 2016-09-03     3.300
# 2           Albert Park      2    h        Thomson 2016-09-03     3.300
# 3            Alphington      4    h          Brace 2016-09-03     6.400
# 4            Alphington      3    h         Jellis 2016-09-03     6.400
# ...                 ...    ...  ...            ...        ...       ...
# 27098        Noble Park      3    h            C21 2017-09-30    22.700
# 27099         Reservoir      3    u             RW 2017-09-30    12.000
# 27100     Roxburgh Park      4    h          Raine 2017-09-30    20.600
# 27101  Springvale South      3    h      Harcourts 2017-09-30    22.200
# 27102       Westmeadows      4    h          Barry 2017-09-30    16.500
#
#        Postcode  Bedroom  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# ...

# %% [markdown]
# **Let's check the summary of the data**

# %%
data.describe()
# Out:
#           Rooms                           Date  Distance  Postcode   Bedroom  \
# count 27103.000                          27103 27102.000 27102.000 20678.000
# mean      2.992  2017-05-23 12:25:09.441759488    11.280  3113.787     3.046
# min       1.000            2016-01-28 00:00:00     0.000  3000.000     0.000
# 25%       2.000            2016-11-19 00:00:00     6.400  3046.000     2.000
# 50%       3.000            2017-07-08 00:00:00    10.500  3088.000     3.000
# 75%       4.000            2017-10-28 00:00:00    14.000  3153.000     4.000
# max      16.000            2018-03-17 00:00:00    48.100  3978.000    20.000
# std       0.955                            NaN     6.784   111.129     0.955
#
#        Bathroom       Car  Landsize  BuildingArea  YearBuilt  Propertycount  \
# count 20672.000 20297.000 17873.000     10529.000  11985.000      27103.000
# mean      1.592     1.716   560.537       154.512   1966.618       7564.741
# ...

# %%
data.describe().T
# Out:
#                   count                           mean                  min  \
# Rooms         27103.000                          2.992                1.000
# Date              27103  2017-05-23 12:25:09.441759488  2016-01-28 00:00:00
# Distance      27102.000                         11.280                0.000
# Postcode      27102.000                       3113.787             3000.000
# Bedroom       20678.000                          3.046                0.000
# Bathroom      20672.000                          1.592                0.000
# Car           20297.000                          1.716                0.000
# Landsize      17873.000                        560.537               50.000
# BuildingArea  10529.000                        154.512               11.000
# YearBuilt     11985.000                       1966.618             1850.000
# Propertycount 27103.000                       7564.741               83.000
# ...

# %%
# total numbers of unique values in the postcode column
data["Postcode"].nunique()
# Out:
# 209

# %%
#Count and Percentage of Categoical Levels in each column

#Making a list of all categorical variables
cat_cols=["Suburb", "Type", "SellerG", "Regionname"]

# %%
#Printing the count of unique categorical levels in each column
for column in cat_cols:
  print(data[column].value_counts())
  print("-"*50)
# Out:
# Suburb
# Reservoir         724
# Bentleigh East    493
# Richmond          437
# Preston           410
# Brunswick         383
#                  ...
# Wandin North        1
# Ferny Creek         1
# Tecoma              1
# Montrose            1
# viewbank            1
# Name: count, Length: 345, dtype: int64
# --------------------------------------------------
# Type
# h    18394
# u     5882
# t     2827
# Name: count, dtype: int64
# --------------------------------------------------
# SellerG
# Nelson           2733
# Jellis           2516
# Barry            2385
# hockingstuart    2096
# Ray              1574
#                  ...
# Allan               1
# Jim                 1
# iProperty           1
# Batty               1
# Icon                1
# Name: count, Length: 347, dtype: int64
# --------------------------------------------------
# Regionname
# Southern Metropolitan         8480
# Northern Metropolitan         7809
# Western Metropolitan          5792
# ...

# %% [markdown]
# **There are two ways to handle missing values: Deleting the missing values and Imputting the missing values**

# %%
#Printing the percentage of unique categorical levels in each column
for column in cat_cols:
  print(data[column].value_counts(normalize=True))
  print("-"*50)
# Out:
# Suburb
# Reservoir        0.027
# Bentleigh East   0.018
# Richmond         0.016
# Preston          0.015
# Brunswick        0.014
#                   ...
# Wandin North     0.000
# Ferny Creek      0.000
# Tecoma           0.000
# Montrose         0.000
# viewbank         0.000
# Name: proportion, Length: 345, dtype: float64
# --------------------------------------------------
# Type
# h   0.679
# u   0.217
# t   0.104
# Name: proportion, dtype: float64
# --------------------------------------------------
# SellerG
# Nelson          0.101
# Jellis          0.093
# Barry           0.088
# hockingstuart   0.077
# Ray             0.058
#                  ...
# Allan           0.000
# Jim             0.000
# iProperty       0.000
# Batty           0.000
# Icon            0.000
# Name: proportion, Length: 347, dtype: float64
# --------------------------------------------------
# Regionname
# Southern Metropolitan        0.313
# Northern Metropolitan        0.288
# ...
